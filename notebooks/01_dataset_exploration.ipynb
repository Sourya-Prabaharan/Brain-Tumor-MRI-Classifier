# %% [markdown]
# # Brain MRI Dataset Exploration
#
# This notebook is a lightweight companion to the training scripts. Use it to inspect class balance, view sample images, and review generated result artifacts.

# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from dataset import CLASSES, build_metadata, summarize_class_distribution

DATA_DIR = PROJECT_ROOT / 'data' / 'brain_mri'
RESULTS_DIR = PROJECT_ROOT / 'results'

# %% [markdown]
# ## Class Distribution

# %%
train_df, val_df, test_df = build_metadata(DATA_DIR)
distribution = summarize_class_distribution(('train', train_df), ('validation', val_df), ('test', test_df))
distribution

# %% [markdown]
# ## Generated Figures

# %%
figures = [
    'class_distribution.png',
    'training_curves.png',
    'confusion_matrix.png',
    'sample_predictions.png',
    'misclassifications.png',
    'gradcam_examples.png',
]

for figure in figures:
    path = RESULTS_DIR / figure
    if path.exists():
        image = plt.imread(path)
        plt.figure(figsize=(10, 5))
        plt.imshow(image)
        plt.title(figure)
        plt.axis('off')
        plt.show()
